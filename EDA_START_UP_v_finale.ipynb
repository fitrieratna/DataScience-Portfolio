# %% [markdown]
# <a href="https://colab.research.google.com/github/fitrieratna/notebook/blob/master/EDA_START_UP_v_finale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-Explore

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import chardet

# %%
# To connect Google Drive (GDrive) with Colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
f = open('/content/gdrive/My Drive/data-analysis-science/investments_VC.csv','rb')
line = f.readline()
print(chardet.detect(line))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
data = pd.read_csv('/content/gdrive/My Drive/data-analysis-science/investments_VC.csv', encoding='unicode_escape' )

# %%
data.head(10)
# Out:
#                           permalink                name  ... round_G round_H
# 0             /organization/waywire            #waywire  ...     0.0     0.0
# 1   /organization/tv-communications  &TV Communications  ...     0.0     0.0
# 2     /organization/rock-your-paper   'Rock' Your Paper  ...     0.0     0.0
# 3    /organization/in-touch-network   (In)Touch Network  ...     0.0     0.0
# 4    /organization/r-ranch-and-mine  -R- Ranch and Mine  ...     0.0     0.0
# 5        /organization/club-domains       .Club Domains  ...     0.0     0.0
# 6        /organization/fox-networks       .Fox Networks  ...     0.0     0.0
# 7             /organization/0-6-com             0-6.com  ...     0.0     0.0
# 8    /organization/004-technologies    004 Technologies  ...     0.0     0.0
# 9  /organization/01games-technology  01Games Technology  ...     0.0     0.0
#
# [10 rows x 39 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54294 entries, 0 to 54293
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   permalink             49438 non-null  object
#  1   name                  49437 non-null  object
#  2   homepage_url          45989 non-null  object
#  3   category_list         45477 non-null  object
#  4    market               45470 non-null  object
#  5    funding_total_usd    49438 non-null  object
#  6   status                48124 non-null  object
#  7   country_code          44165 non-null  object
#  8   state_code            30161 non-null  object
#  9   region                44165 non-null  object
#  10  city                  43322 non-null  object
#  11  funding_rounds        49438 non-null  float64
#  12  founded_at            38554 non-null  object
#  13  founded_month         38482 non-null  object
#  14  founded_quarter       38482 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', ' market ',
#        ' funding_total_usd ', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H'],
#       dtype='object')

# %%
missing_data = data.isnull()

for column in missing_data.columns.values.tolist():
 print (column)
 print (missing_data[column].value_counts())
 print("")
# Out:
# permalink
# False    49438
# True      4856
# Name: permalink, dtype: int64
#
# name
# False    49437
# True      4857
# Name: name, dtype: int64
#
# homepage_url
# False    45989
# True      8305
# Name: homepage_url, dtype: int64
#
# category_list
# False    45477
# True      8817
# Name: category_list, dtype: int64
#
#  market
# False    45470
# True      8824
# Name:  market , dtype: int64
#
#  funding_total_usd
# False    49438
# True      4856
# Name:  funding_total_usd , dtype: int64
#
# status
# False    48124
# True      6170
# Name: status, dtype: int64
#
# country_code
# False    44165
# True     10129
# Name: country_code, dtype: int64
#
# state_code
# False    30161
# True     24133
# Name: state_code, dtype: int64
#
# region
# False    44165
# True     10129
# Name: region, dtype: int64
#
# city
# False    43322
# True     10972
# Name: city, dtype: int64
#
# funding_rounds
# False    49438
# True      4856
# Name: funding_rounds, dtype: int64
#
# founded_at
# ...

# %%
#closer look on value count on each feature  
for n in data.columns.values.tolist():
    print(n)
    print (data[n].value_counts())
    print("")
# Out:
# permalink
# /organization/prysm                               2
# /organization/treasure-valley-urology-services    2
# /organization/solutionary                         1
# /organization/inspire-health                      1
# /organization/gmi-ratings                         1
#                                                  ..
# /organization/teleradiology-holdings-inc          1
# /organization/deminos                             1
# /organization/reefedge                            1
# /organization/ides-technologies                   1
# /organization/cigital                             1
# Name: permalink, Length: 49436, dtype: int64
#
# name
# Spire        4
# Roost        4
# Roadmap      3
# Hubbub       3
# Cue          3
#             ..
# AxoGen       1
# Reeher       1
# Smart Eye    1
# FanSnap      1
# Mojeek       1
# Name: name, Length: 49350, dtype: int64
#
# homepage_url
# http://youbeauty.com           2
# http://www.justanswer.com      2
# ...

# %%
data.tail(5)
# Out:
#       permalink name homepage_url  ... round_F round_G round_H
# 54289       NaN  NaN          NaN  ...     NaN     NaN     NaN
# 54290       NaN  NaN          NaN  ...     NaN     NaN     NaN
# 54291       NaN  NaN          NaN  ...     NaN     NaN     NaN
# 54292       NaN  NaN          NaN  ...     NaN     NaN     NaN
# 54293       NaN  NaN          NaN  ...     NaN     NaN     NaN
#
# [5 rows x 39 columns]

# %%
data.duplicated().sum()
# Out:
# 4855

# %% [markdown]
# Seeing this we can say that the data has duplicates, missing values, and there's spacing in column 'market' and 'funding_total_usd'.

# %% [markdown]
# # Data Wrenching
#
#
# > 1. Fixing space in columns
#
# > 2. Remove Duplicates
#
# > 3. Change uncommon data format
#
# > 4. Handling other missing values
#
# > 5. Detecting & Handling Outlier

# %% [markdown]
# ## 1. Fixing space in column
#
#
# ---

# %%
data = data[~data.name.isna()] #remove companies with no name

# %%
data1 = data.copy()

# %%
data1.rename(columns= {' market ':'market', ' funding_total_usd ':'funding_total_usd' }, inplace= True)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49437 entries, 0 to 49437
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   permalink             49437 non-null  object
#  1   name                  49437 non-null  object
#  2   homepage_url          45988 non-null  object
#  3   category_list         45476 non-null  object
#  4   market                45469 non-null  object
#  5   funding_total_usd     49437 non-null  object
#  6   status                48123 non-null  object
#  7   country_code          44165 non-null  object
#  8   state_code            30161 non-null  object
#  9   region                44165 non-null  object
#  10  city                  43322 non-null  object
#  11  funding_rounds        49437 non-null  float64
#  12  founded_at            38553 non-null  object
#  13  founded_month         38481 non-null  object
#  14  founded_quarter       38481 non-null  object
# ...

# %%
data1.name.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Remove Duplicate (All NaN in whole columns)
#
# ---

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data1.tail()
# Out:
#                                                permalink  ... round_H
# 49433                                /organization/zzish  ...     0.0
# 49434  /organization/zznode-science-and-technology-co...  ...     0.0
# 49435                          /organization/zzzzapp-com  ...     0.0
# 49436                         /organization/a-list-games  ...     0.0
# 49437                                    /organization/x  ...     0.0
#
# [5 rows x 39 columns]

# %%
print('Duplicated entries:',data1.duplicated().sum())
data1[data1.duplicated()].isna().sum(axis=0)
# Out:
# Duplicated entries: 0
# permalink               0
# name                    0
# homepage_url            0
# category_list           0
# market                  0
# funding_total_usd       0
# status                  0
# country_code            0
# state_code              0
# region                  0
# city                    0
# funding_rounds          0
# founded_at              0
# founded_month           0
# founded_quarter         0
# founded_year            0
# first_funding_at        0
# last_funding_at         0
# seed                    0
# venture                 0
# equity_crowdfunding     0
# undisclosed             0
# convertible_note        0
# debt_financing          0
# angel                   0
# grant                   0
# private_equity          0
# post_ipo_equity         0
# post_ipo_debt           0
# secondary_market        0
# product_crowdfunding    0
# round_A                 0
# round_B                 0
# round_C                 0
# ...

# %%
#data1.dropna(how='all', inplace=True)

# %%
data2 = data1.copy()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49437 entries, 0 to 49437
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   permalink             49437 non-null  object
#  1   name                  49437 non-null  object
#  2   homepage_url          45988 non-null  object
#  3   category_list         45476 non-null  object
#  4   market                45469 non-null  object
#  5   funding_total_usd     49437 non-null  object
#  6   status                48123 non-null  object
#  7   country_code          44165 non-null  object
#  8   state_code            30161 non-null  object
#  9   region                44165 non-null  object
#  10  city                  43322 non-null  object
#  11  funding_rounds        49437 non-null  float64
#  12  founded_at            38553 non-null  object
#  13  founded_month         38481 non-null  object
#  14  founded_quarter       38481 non-null  object
# ...

# %%
missing_data = data2.isnull()

for column in missing_data.columns.values.tolist():
 print (column)
 print (missing_data[column].value_counts())
 print("")
# Out:
# permalink
# False    49437
# Name: permalink, dtype: int64
#
# name
# False    49437
# Name: name, dtype: int64
#
# homepage_url
# False    45988
# True      3449
# Name: homepage_url, dtype: int64
#
# category_list
# False    45476
# True      3961
# Name: category_list, dtype: int64
#
# market
# False    45469
# True      3968
# Name: market, dtype: int64
#
# funding_total_usd
# False    49437
# Name: funding_total_usd, dtype: int64
#
# status
# False    48123
# True      1314
# Name: status, dtype: int64
#
# country_code
# False    44165
# True      5272
# Name: country_code, dtype: int64
#
# state_code
# False    30161
# True     19276
# Name: state_code, dtype: int64
#
# region
# False    44165
# True      5272
# Name: region, dtype: int64
#
# city
# False    43322
# True      6115
# Name: city, dtype: int64
#
# funding_rounds
# False    49437
# Name: funding_rounds, dtype: int64
#
# founded_at
# False    38553
# True     10884
# Name: founded_at, dtype: int64
#
# founded_month
# ...

# %%
data2.describe()
# Out:
#        funding_rounds  founded_year  ...       round_G       round_H
# count    49437.000000  38481.000000  ...  4.943700e+04  4.943700e+04
# mean         1.696219   2007.359034  ...  5.767183e+04  1.423226e+04
# std          1.294222      7.579279  ...  5.252365e+06  2.716893e+06
# min          1.000000   1902.000000  ...  0.000000e+00  0.000000e+00
# 25%          1.000000   2006.000000  ...  0.000000e+00  0.000000e+00
# 50%          1.000000   2010.000000  ...  0.000000e+00  0.000000e+00
# 75%          2.000000   2012.000000  ...  0.000000e+00  0.000000e+00
# max         18.000000   2014.000000  ...  1.000000e+09  6.000000e+08
#
# [8 rows x 23 columns]

# %%
data3= data2.copy()

# %%
data3[data3.name=='Dropbox']
# Out:
#                    permalink     name  ... round_G round_H
# 12375  /organization/dropbox  Dropbox  ...     0.0     0.0
#
# [1 rows x 39 columns]

# %% [markdown]
# ## 3. Change Uncommon Format
#
# ---
#
#   Then we tackle this by eliminate the comma and change the type into float, as process following

# %%
data3.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'market',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H'],
#       dtype='object')

# %%
data3['funding_total_usd'] = data3['funding_total_usd'].str.replace(',', '')
data3['funding_total_usd'] = data3['funding_total_usd'].str.replace('-', '')
data3['funding_total_usd'] = data3['funding_total_usd'].str.replace(' ', '')

data3['funding_total_usd'] = pd.to_numeric(data3['funding_total_usd'], errors='coerce')

# %%
data3.dtypes
# Out:
# permalink                object
# name                     object
# homepage_url             object
# category_list            object
# market                   object
# funding_total_usd       float64
# status                   object
# country_code             object
# state_code               object
# region                   object
# city                     object
# funding_rounds          float64
# founded_at               object
# founded_month            object
# founded_quarter          object
# founded_year            float64
# first_funding_at         object
# last_funding_at          object
# seed                    float64
# venture                 float64
# equity_crowdfunding     float64
# undisclosed             float64
# convertible_note        float64
# debt_financing          float64
# angel                   float64
# grant                   float64
# private_equity          float64
# post_ipo_equity         float64
# post_ipo_debt           float64
# ...

# %%
missing_data = data3.isnull()

for column in missing_data.columns.values.tolist():
 print (column)
 print (missing_data[column].value_counts())
 print("")
# Out:
# permalink
# False    49437
# Name: permalink, dtype: int64
#
# name
# False    49437
# Name: name, dtype: int64
#
# homepage_url
# False    45988
# True      3449
# Name: homepage_url, dtype: int64
#
# category_list
# False    45476
# True      3961
# Name: category_list, dtype: int64
#
# market
# False    45469
# True      3968
# Name: market, dtype: int64
#
# funding_total_usd
# False    40906
# True      8531
# Name: funding_total_usd, dtype: int64
#
# status
# False    48123
# True      1314
# Name: status, dtype: int64
#
# country_code
# False    44165
# True      5272
# Name: country_code, dtype: int64
#
# state_code
# False    30161
# True     19276
# Name: state_code, dtype: int64
#
# region
# False    44165
# True      5272
# Name: region, dtype: int64
#
# city
# False    43322
# True      6115
# Name: city, dtype: int64
#
# funding_rounds
# False    49437
# Name: funding_rounds, dtype: int64
#
# founded_at
# False    38553
# True     10884
# Name: founded_at, dtype: int64
# ...

# %% [markdown]
# All set. Now we can choose of which columns we'd like to use to do further analysis :
#
# name (1 missing data),
# market (3968 missing data),
# status (1314 missing data)
# country_code (5273 missing data)
# region (5273 missing data)
# funding_rounds
# seed
# venture
# equity_crowdfunding
# angel
# grant
# post_ipo_equity
# funding_total_USD (8531 missing data) --set into 0
# same application for round A until round H.

# %%
data4=data3.copy()

# %% [markdown]
# ##4. Handling other missing value
#
#
# ---
#
# As we can see from above missing data from all categories, we'll see the missing data how it's look like. From the result below we see all missing data are already fulfilled with NaN values, considering when doing numeric plotting, NaN values will be neglected then we leave it here.
#
# Since we'll be using funding_total_USD a lot, we replace the NaN value into 0.

# %%
data4['category_list'].isnull().sum()
# Out:
# 3961

# %%
data4[data4['category_list'].isnull()].head(3)
# Out:
#                    permalink        name  ... round_G round_H
# 48       /organization/12bis       12Bis  ...     0.0     0.0
# 61  /organization/16lab-inc-  16Lab Inc.  ...     0.0     0.0
# 72     /organization/1d4-pty     1d4 Pty  ...     0.0     0.0
#
# [3 rows x 39 columns]

# %%
data4[data4['funding_total_usd'].isnull()].head(3)
# Out:
#                          permalink              name  ... round_G round_H
# 8   /organization/004-technologies  004 Technologies  ...     0.0     0.0
# 11           /organization/1-4-all           1-4 All  ...     0.0     0.0
# 12     /organization/1-800-dentist     1-800-DENTIST  ...     0.0     0.0
#
# [3 rows x 39 columns]

# %%
data4['funding_total_usd'].replace(np.nan, 0, inplace=True)
data4[data4['funding_total_usd'].isnull()].head(3)
# Out:
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list, market, funding_total_usd, status, country_code, state_code, region, city, funding_rounds, founded_at, founded_month, founded_quarter, founded_year, first_funding_at, last_funding_at, seed, venture, equity_crowdfunding, undisclosed, convertible_note, debt_financing, angel, grant, private_equity, post_ipo_equity, post_ipo_debt, secondary_market, product_crowdfunding, round_A, round_B, round_C, round_D, round_E, round_F, round_G, round_H]
# Index: []

# %% [markdown]
# ##5. Detecting and Handling Outlier
#
#
# ---

# %%
import seaborn as sns

# %% [markdown]
# We'll investigate on each numeric categories and see whether they have an outlier.
#
# 1. Total Funding USD
# 2. Seed

# %% [markdown]
# 1. Total Funding USD
#
# ---

# %%
sns.boxplot(data4['funding_total_usd'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(data4['funding_total_usd'], bins=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import math
data_log_fund = data4['funding_total_usd'][data4['funding_total_usd']!=0]
log_data = [math.log(d) for d in data_log_fund]
sns.distplot(log_data, bins=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_log_fund[data4['funding_total_usd'] >= 1000000000]
# Out:
# 1868     1.112000e+09
# 2639     1.000000e+09
# 5532     1.000000e+09
# 7107     1.200000e+09
# 7234     1.500000e+09
# 7328     2.400000e+09
# 7977     5.162513e+09
# 8664     5.700000e+09
# 8889     1.201000e+09
# 9155     3.200000e+09
# 12375    1.107215e+09
# 14705    2.425700e+09
# 15315    3.500000e+09
# 15360    1.451000e+09
# 15569    2.351140e+09
# 18075    1.137000e+09
# 29882    1.371634e+09
# 34329    1.900000e+09
# 35399    2.250000e+09
# 36911    5.800000e+09
# 38289    2.600000e+09
# 38601    1.055750e+09
# 39127    1.062700e+09
# 39482    1.045040e+09
# 39577    1.567504e+09
# 42470    1.200000e+09
# 44673    1.160167e+09
# 44772    1.507450e+09
# 45671    1.498515e+09
# 45815    3.007950e+10
# 47007    1.050000e+09
# 48198    1.100000e+09
# 48679    1.320000e+09
# 48936    2.000000e+09
# Name: funding_total_usd, dtype: float64

# %%
Q1 = data4['funding_total_usd'].quantile(0.25)
Q3 = data4['funding_total_usd'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = (Q1 - 1.5 * IQR) #MIN
upper_bound = (Q3 + 1.5 * IQR) #MAX
print (lower_bound, Q1, Q3, upper_bound)
# Out:
# -10033582.0 50000.0 6772388.0 16855970.0

# %%
without_outlier = data4[(data4['funding_total_usd']< upper_bound)]

# %% [markdown]
# 2. Seed
#
# ---

# %%
sns.boxplot(data4['seed'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data4['seed'][data4['seed'] != 0]
# Out:
# 0        1750000.0
# 2          40000.0
# 3        1500000.0
# 9          41250.0
# 10         40000.0
#            ...
# 49428     225000.0
# 49431     495000.0
# 49433     320000.0
# 49435      71525.0
# 49436    9300000.0
# Name: seed, Length: 13839, dtype: float64

# %%
#calculate interquartile range


Q1s = data4['seed'][data4['seed'] != 0].quantile(0.25)
Q2s = data4['seed'][data4['seed'] != 0].quantile(0.50)
Q3s = data4['seed'][data4['seed'] != 0].quantile(0.75)
IQRs = Q3-Q1

#same code as
#q25, q50, q75 = np.percentile(data2['seed'][data2['seed']!=0], [25,50,75])
#iqr = q75-q50

#calculate min/max limits tp be considered as outlier

lower_bounds = Q1 - 1.5*(IQR)
upper_bounds = Q3 + 1.5*(IQR)

print (lower_bounds, Q1s, Q2s, Q3s, upper_bounds)
# Out:
# -10033582.0 65000.0 300000.0 1000000.0 16855970.0

# %%
#identify points of seed outlier
withoutoutlier_seed= data4[(data4['seed'] < upper_bounds)]

withoutoutlier_seed = withoutoutlier_seed.rename(columns={0: 'seed'})
withoutoutlier_seed.head(2)
# Out:
#                          permalink                name  ... round_G round_H
# 0            /organization/waywire            #waywire  ...     0.0     0.0
# 1  /organization/tv-communications  &TV Communications  ...     0.0     0.0
#
# [2 rows x 39 columns]

# %%
plt.hist(withoutoutlier_seed['seed'][withoutoutlier_seed['seed']!=0].dropna(), bins=30,color = 'tan' )
# Out:
# (array([8.341e+03, 2.183e+03, 1.204e+03, 8.610e+02, 4.110e+02, 3.330e+02,
#         1.600e+02, 1.010e+02, 5.800e+01, 6.000e+01, 2.800e+01, 2.900e+01,
#         1.800e+01, 1.000e+01, 7.000e+00, 7.000e+00, 2.000e+00, 3.000e+00,
#         3.000e+00, 4.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 2.000e+00]),
#  array([1.40000000e+01, 5.00940800e+05, 1.00186760e+06, 1.50279440e+06,
#         2.00372120e+06, 2.50464800e+06, 3.00557480e+06, 3.50650160e+06,
#         4.00742840e+06, 4.50835520e+06, 5.00928200e+06, 5.51020880e+06,
#         6.01113560e+06, 6.51206240e+06, 7.01298920e+06, 7.51391600e+06,
#         8.01484280e+06, 8.51576960e+06, 9.01669640e+06, 9.51762320e+06,
#         1.00185500e+07, 1.05194768e+07, 1.10204036e+07, 1.15213304e+07,
#         1.20222572e+07, 1.25231840e+07, 1.30241108e+07, 1.35250376e+07,
#         1.40259644e+07, 1.45268912e+07, 1.50278180e+07]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# # Exploratory Data Analysis
#
# ---

# %% [markdown]
# ### 1. Start Up

# %% [markdown]
# > **Top 5 Country in terms of Start Up Number**

# %%
count_country = data4.country_code.value_counts().sort_values(ascending=False)
count_country[count_country>=100]
# Out:
# USA    28793
# GBR     2642
# CAN     1405
# CHN     1239
# DEU      968
# FRA      866
# IND      849
# ISR      682
# ESP      549
# RUS      368
# SWE      315
# AUS      314
# ITA      308
# NLD      307
# IRL      306
# SGP      299
# BRA      293
# CHL      285
# JPN      284
# KOR      246
# CHE      222
# DNK      210
# FIN      194
# ARG      149
# BEL      149
# HKG      126
# TUR      124
# AUT      103
# Name: country_code, dtype: int64

# %%
plt.style.use('ggplot')
sns.distplot(data2.country_code.value_counts(),kde=False) #kde:kernel density estimate

#USA
plt.axvline(data2.loc[data2.country_code=='USA'].shape[0],color='black',linestyle ="-.",linewidth=1)
plt.text(data2.loc[data2.country_code=='USA'].shape[0]-5000, 80,"   USA \n28793")

#Great Britain
plt.axvline(data2.loc[data2.country_code=='GBR'].shape[0],color='m',linestyle ="--",linewidth=1)
plt.text(data2.loc[data2.country_code=='GBR'].shape[0]+100, 70,"GBR \n2642",color='m')

#Canada
plt.axvline(data2.loc[data2.country_code=='CAN'].shape[0],color='midnightblue',linestyle ="--",linewidth=1)
plt.text(data2.loc[data2.country_code=='CAN'].shape[0]+100, 50,"CAN \n1405",color='midnightblue')

#China
plt.axvline(data2.loc[data2.country_code=='CHN'].shape[0],color='red',linestyle ="--",linewidth=1)
plt.text(data2.loc[data2.country_code=='CHN'].shape[0]+100, 35,"ChN \n1239",color='red')


#Deutschland / Germany
plt.axvline(data2.loc[data2.country_code=='DEU'].shape[0],color='olivedrab',linestyle ="--",linewidth=1)
plt.text(data2.loc[data2.country_code=='DEU'].shape[0]-2000, 20,"DEU \n968",color='olivedrab')

plt.title('Distribution of start-ups\nAcross countries',loc='left',pad=10)
plt.xlabel('Quantity of Start-ups')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > **Start Up Status**

# %%
data4.status.value_counts()
# Out:
# operating    41829
# acquired      3692
# closed        2602
# Name: status, dtype: int64

# %%
color = ['#99ffd5', '#ffdb99', '#ac99ff']
plt.figure(figsize = (8,8))
data4.status.value_counts().plot(kind='pie',colors = color, shadow=False, explode=(0, 0, 0.15), startangle=90,autopct='%1.1f%%')
plt.title('Start Up Status')
plt.show()

# %% [markdown]
# > **Startup's Founded Year Distribution**

# %%
import datetime as dt
data4['founded_year'] = pd.DatetimeIndex(data4['founded_month']).year
founded_year = data4[~data4.founded_year.isna()]['founded_year'].astype('int')

#due to inconsistent year between founded_year and year in founded_month
#data4.drop(['founded_at'], axis=1, inplace=True)

data4.head(10)
# Out:
#                           permalink                name  ... round_G round_H
# 0             /organization/waywire            #waywire  ...     0.0     0.0
# 1   /organization/tv-communications  &TV Communications  ...     0.0     0.0
# 2     /organization/rock-your-paper   'Rock' Your Paper  ...     0.0     0.0
# 3    /organization/in-touch-network   (In)Touch Network  ...     0.0     0.0
# 4    /organization/r-ranch-and-mine  -R- Ranch and Mine  ...     0.0     0.0
# 5        /organization/club-domains       .Club Domains  ...     0.0     0.0
# 6        /organization/fox-networks       .Fox Networks  ...     0.0     0.0
# 7             /organization/0-6-com             0-6.com  ...     0.0     0.0
# 8    /organization/004-technologies    004 Technologies  ...     0.0     0.0
# 9  /organization/01games-technology  01Games Technology  ...     0.0     0.0
#
# [10 rows x 39 columns]

# %%
data4['founded_year'][data4['founded_year'] >= 1990].value_counts()
# Out:
# 2012.0    5211
# 2011.0    4904
# 2013.0    4044
# 2010.0    3773
# 2009.0    2979
# 2008.0    2348
# 2007.0    2331
# 2006.0    1807
# 2014.0    1469
# 2005.0    1418
# 2004.0    1156
# 2003.0     965
# 2000.0     888
# 2002.0     788
# 1999.0     758
# 2001.0     741
# 1998.0     437
# 1997.0     359
# 1996.0     304
# 1995.0     224
# 1994.0     156
# 1993.0     129
# 1992.0     115
# 1991.0      92
# 1990.0      87
# Name: founded_year, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(10,5))
sns.distplot(founded_year[founded_year>1980])
plt.title('Founded year distribution')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data4[data4['name']=='Mosaic']
# Out:
#                         permalink    name  ... round_G round_H
# 27558  /organization/solar-mosaic  Mosaic  ...     0.0     0.0
#
# [1 rows x 39 columns]

# %%
data4['founded_year'].describe()
data4[data4['founded_year']==1902.0]
# Out:
#                                permalink                 name  ... round_G round_H
# 42802  /organization/the-miriam-hospital  The Miriam Hospital  ...     0.0     0.0
# 49126              /organization/ziegler              Ziegler  ...     0.0     0.0
#
# [2 rows x 39 columns]

# %% [markdown]
# > **When Tech Titans Companies has been founded?**
#
#
# As we know FANG+ companies (FACEBOOK, AMAZON, NETFLIX, GOOGLE, ALIBABA) are the take titans whom outperformed the wider market since the coronavirus (COVID-19) pandemic spurred record sell-offs in March. Unlike other stocks which met their dip price in this time, FANG+ companies are hype up even until 80% take up rate compares to their lowest in early March due to its performance and forward looking valuation.
#
# Hence knowing when FANG+ companies are founded is interesting thing to visualize.

# %%
#data['founded_at'] = pd.to_datetime(data4['founded_at'], errors = 'coerce' )

Facebook_founded_year = data4['founded_year'][data['name']=="Facebook"].values[0]
Amazon_founded_year  = data4['founded_year'][data['name']=="Amazon"].values[0]
Netflix_founded_year  = data4['founded_year'][data['name']=="Netflix"].values[0]
Google_founded_year  = data4['founded_year'][data['name']=="Google"].values[0]
Alibaba_founded_year  = data4['founded_year'][data['name']=="Alibaba"].values[0]


print('Facebook_founded_year :' ,Facebook_founded_year)
print('Amazon_founded_year :' ,Amazon_founded_year)
print('Netflix_founded_year :' ,Netflix_founded_year)
print('Google_founded_year :' ,Google_founded_year)
print('Alibaba_founded_year :' ,Alibaba_founded_year)
# Out:
# Facebook_founded_year : 2004.0
# Amazon_founded_year : 1994.0
# Netflix_founded_year : 1997.0
# Google_founded_year : 1998.0
# Alibaba_founded_year : 1999.0

# %%
import seaborn as sns
sns.set()

plt.rcParams['figure.figsize'] = 15,6
data['name'][data["founded_year"] >= 1990].groupby(data["founded_year"]).count().plot(kind="line")
plt.ylabel('Companies Number Founded')

plt.axvline(Facebook_founded_year,color='royalblue',linestyle ="--")
plt.text(Facebook_founded_year+0.15, 4500,"Facebook \n (2004)")

plt.axvline(Amazon_founded_year,color='black',linestyle ="--")
plt.text(Amazon_founded_year+0.15, 2000,"Amazon \n(1994)")

plt.axvline(Netflix_founded_year,color='orange',linestyle ="--")
plt.text(Netflix_founded_year+0.15, 3000,"Netflix \n(1997)")

plt.axvline(Google_founded_year,color='m',linestyle ="--")
plt.text(Google_founded_year+0.15, 3700,"Google \n(1998)")

plt.axvline(Alibaba_founded_year,color='r',linestyle ="--")
plt.text(Alibaba_founded_year+0.15, 4200,"Alibaba \n(1999)")

plt.title("When the FANG+ Companies Found ?", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %% [markdown]
# ##2. Market
#
# ---

# %% [markdown]
# > **Top 15 Start Up Market Worldwide**

# %%
data4['market'].value_counts()[:5]
# Out:
#  Software          4620
#  Biotechnology     3688
#  Mobile            1983
#  E-Commerce        1805
#  Curated Web       1655
# Name: market, dtype: int64

# %%
market = data4['market'].value_counts()
market=market[(market>1000)][:10].to_frame()

plt.figure()
ax1=sns.barplot(y=market.index,x=market.market,orient='h',palette='pastel')
ax1.set_title('Top 10 Market of Start-Ups Worldwide',pad=20)
ax1.set_xlabel('Market Counts Global')
plt.show()

# %%
market_con=data4.groupby('country_code')['market'].value_counts().to_frame()

fig,axes=plt.subplots(2,2,figsize=(20,10))
cont=['USA','CHN', 'IDN', 'IND']
for con,ax in zip(cont,range(1,5)):
    ax=plt.subplot(2,2,ax)
    ax=sns.barplot(y=market_con.loc[con].index[0:10],x=market_con.loc[con].market[0:10],orient='h',palette="coolwarm")
    ax.set_xlabel('Market Counts In {}'.format(con))
plt.suptitle('Top 10 Market of Start-ups',size=40)
plt.show()

# %%
data4['count'] = 1
country_market = data4[['count','country_code','market']].groupby(['country_code','market']).agg({'count': 'sum'})
# Change: groupby state_office and divide by sum
country_market_pct = country_market.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))
country_market_pct.reset_index(inplace = True)

# %%
IDN_market_pct = country_market_pct[country_market_pct['country_code'] == "IDN"]
IDN_market_pct = IDN_market_pct.sort_values('count',ascending = False)[0:10]

# %%
## IDN
plt.rcParams['figure.figsize'] =8,8
labels = list(IDN_market_pct['market'])+['Other...']
sizes = list(IDN_market_pct['count'])+[100-IDN_market_pct['count'].sum()]
explode = (0.18, 0.12, 0.09,0,0,0,0,0,0,0,0.01)
colors =  ['mistyrose','salmon','cyan'] +['papayawhip']*8

plt.pie(sizes, explode = explode, colors = colors ,labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=70)
plt.axis('equal')
plt.tight_layout()
plt.title("IDN start up market", fontdict=None, position= [0.48,1.1], size = 'x-large')

plt.show()

# %% [markdown]
# > **Most Favorable Startup Category Worldwide**

# %%
# %%time
category_list=data4.category_list.str.split('|').to_list()
categ=[]

for i in category_list:
    if isinstance(i,list):
        categ=categ+i
categ=list(filter(None,categ))
categ=' '.join(categ)
# Out:
# CPU times: user 28.2 s, sys: 392 ms, total: 28.6 s
# Wall time: 28.7 s

# %%
import wordcloud
w=wordcloud.WordCloud(background_color='White',scale=32)

# %%
fig = plt.figure(figsize=(12, 8))
w.generate(categ)
plt.axis('off')
plt.imshow(w)

# %% [markdown]
# ## 3. Funding
# ---

# %% [markdown]
# > **Total Funding Distribution**

# %%
def funding_information(data,name):
    company = data4[data4['name'] == name]
    print ("Company : ", name)
    print ("Total Funding : ", company.funding_total_usd.values[0] , " $")
    print ("Seed Funding : ", company.seed.values[0] , " $")
    print ("Angel Funding :", company.angel.values[0] , " $")
    print ("Grant Funding : ",company.grant.values[0] , " $")
    print ("Product Crowd Funding : ",company.product_crowdfunding.values[0] , " $")
    print ("Equity Crowd Funding : ",company.equity_crowdfunding.values[0] , " $")
    print ("Undisclode Funding : ", company.undisclosed.values[0] , " $")
    print ("Convertible Note : ", company.convertible_note.values[0] , " $")
    print ("Debt Financing : ", company.debt_financing.values[0] , " $")
    print ("Private Equity : ",company.private_equity.values[0] , " $")
    print ("PostIPO Equity : ",company.post_ipo_equity.values[0] , " $")
    print ("PostIPO Debt : ",company.post_ipo_debt.values[0] , " $")
    print ("Secondary Market : ",company.secondary_market.values[0] , " $")
    print ("Venture Funding : ",company.venture.values[0] , " $")
    print ("Round A funding : ",company.round_A.values[0] , " $")
    print ("Round B funding : ",company.round_B.values[0] , " $")
    print ("Round C funding : ",company.round_C.values[0] , " $")
    print ("Round D funding : ",company.round_D.values[0] , " $")
    print ("Round E funding : ",company.round_E.values[0] , " $")
    print ("Round F funding : ",company.round_F.values[0] , " $")
    print ("Round G funding : ",company.round_G.values[0] , " $")
    print ("Round H funding : ",company.round_H.values[0] , " $")

# %%
data4.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'market',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'seed', 'venture', 'equity_crowdfunding',
#        'undisclosed', 'convertible_note', 'debt_financing', 'angel', 'grant',
#        'private_equity', 'post_ipo_equity', 'post_ipo_debt',
#        'secondary_market', 'product_crowdfunding', 'round_A', 'round_B',
#        'round_C', 'round_D', 'round_E', 'round_F', 'round_G', 'round_H',
#        'count'],
#       dtype='object')

# %%
funding_information(data,"Facebook")
# Out:
# Company :  Facebook
# Total Funding :  2425700000.0  $
# Seed Funding :  0.0  $
# Angel Funding : 500000.0  $
# Grant Funding :  0.0  $
# Product Crowd Funding :  0.0  $
# Equity Crowd Funding :  0.0  $
# Undisclode Funding :  0.0  $
# Convertible Note :  0.0  $
# Debt Financing :  100000000.0  $
# Private Equity :  1710000000.0  $
# PostIPO Equity :  0.0  $
# PostIPO Debt :  0.0  $
# Secondary Market :  0.0  $
# Venture Funding :  615200000.0  $
# Round A funding :  12700000.0  $
# Round B funding :  27500000.0  $
# Round C funding :  375000000.0  $
# Round D funding :  200000000.0  $
# Round E funding :  0.0  $
# Round F funding :  0.0  $
# Round G funding :  0.0  $
# Round H funding :  0.0  $

# %%
plt.rcParams['figure.figsize'] = 10,6
plt.hist(data4['funding_total_usd'].dropna(), bins=30)
plt.ylabel('Count')
plt.xlabel('Funding (USD)')
plt.title("Distribution of total funding ", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 10,6
plt.hist(without_outlier['funding_total_usd'].dropna(), bins=30,color = 'Blue' )

plt.ylabel('Count')
plt.xlabel('Funding (usd)')
plt.title("Distribution of total funding ", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %%
top_fund=(data4.funding_total_usd.sort_values(ascending=False)[0:4948].sum())/(data4.funding_total_usd.sort_values(ascending=False).sum())
plt.rcParams['figure.figsize'] = 3,3
cmap = plt.get_cmap("tab20c")
outer_colors = cmap(np.arange(2)*13)
plt.pie([top_fund,1-top_fund], radius=2, colors=outer_colors,labels=['Top 10%','Others'],autopct='%1.1f%%',
       wedgeprops=dict(width=0.5, edgecolor='w'))
plt.title('Top 10% Companies\' total funding',pad=100)
plt.show()

# %% [markdown]
# > **Total Funding in Various Unicorn in 2014**

# %%
data4[(data4['funding_total_usd'] >= 1000000000) & (data4['funding_total_usd'] <= 3000000000) & (data4['founded_year']>=1995)]
# Out:
#                                      permalink  ... count
# 1868                     /organization/alibaba  ...     1
# 7107                   /organization/cape-wind  ...     1
# 7328           /organization/carestream-health  ...     1
# 8889                    /organization/cloudera  ...     1
# 12375                    /organization/dropbox  ...     1
# 14705                   /organization/facebook  ...     1
# 15360                     /organization/fisker  ...     1
# 15569                   /organization/flipkart  ...     1
# 18075                    /organization/groupon  ...     1
# 29882               /organization/o3b-networks  ...     1
# 35399  /organization/reliance-jio-infocomm-ltd  ...     1
# 38289                  /organization/sigmacare  ...     1
# 39127                   /organization/snapdeal  ...     1
# 39482                  /organization/solarcity  ...     1
# 39577                   /organization/solyndra  ...     1
# ...

# %%
Facebook_funding_total = data4['funding_total_usd'][data4['name']=="Facebook"].values[0]
Twitter_funding_total  = data4['funding_total_usd'][data4['name']=="Twitter"].values[0]
Uber_funding_total  = data4['funding_total_usd'][data4['name']=="Uber"].values[0]
Cloudera_funding_total  = data4['funding_total_usd'][data4['name']=="Cloudera"].values[0]
Alibaba_funding_total  = data4['funding_total_usd'][data4['name']=="Alibaba"].values[0]

# %%
print('Facebook_funding_total :' ,Facebook_funding_total)
print('Twitter_funding_total :' ,Twitter_funding_total)
print('Uber_funding_total :' ,Uber_funding_total)
print('Cloudera_funding_total :' ,Cloudera_funding_total)
print('Alibaba_funding_total :' ,Alibaba_funding_total)
# Out:
# Facebook_funding_total : 2425700000.0
# Twitter_funding_total : 1160166511.0
# Uber_funding_total : 1507450000.0
# Cloudera_funding_total : 1201000000.0
# Alibaba_funding_total : 1112000000.0

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = 15,6
plt.hist(data4['funding_total_usd'][(data4['funding_total_usd'] >= 1000000000) & (data4['funding_total_usd'] <= 3000000000)].dropna(), bins=30,color = 'lightgreen' ) 

plt.ylabel('Count')
plt.xlabel('Total Funding (USD)')
plt.title("Total Funding of Unicorn companies in 2014", fontdict=None, position= [0.48,1.05], size = 'x-large')

plt.axvline(Facebook_funding_total,color='royalblue',linestyle ="--")
plt.text(Facebook_funding_total+30000000, 1.1,"Facebook")

plt.axvline(Twitter_funding_total,color='black',linestyle ="--")
plt.text(Twitter_funding_total+10000000, 0.4,"Twitter")

plt.axvline(Uber_funding_total,color='orange',linestyle ="--")
plt.text(Uber_funding_total+10000000, 0.9,"Uber")

plt.axvline(Cloudera_funding_total,color='m',linestyle ="--")
plt.text(Cloudera_funding_total+10000000, 0.7,"Cloudera")

plt.axvline(Alibaba_funding_total,color='r',linestyle ="--")
plt.text(Alibaba_funding_total+10000000, 0.1,"Alibaba")

plt.show()

# %%
top_funding = data4.sort_values(by='funding_total_usd', ascending=False)[0:5]
top_funding.head(5)
# Out:
#                                   permalink  ... count
# 45815                 /organization/verizon  ...     1
# 36911                /organization/sberbank  ...     1
# 8664                /organization/clearwire  ...     1
# 7977   /organization/charter-communications  ...     1
# 15315  /organization/first-data-corporation  ...     1
#
# [5 rows x 40 columns]

# %%
data5 = data4.copy()

# %% [markdown]
# > **Seed Funding**

# %%
data5['get_seed_funding'] = data5['seed'].map(lambda s :1  if s > 0 else 0)

# %%
plt.rcParams['figure.figsize'] =5,5
labels = ['No','Get seed funding']
sizes = data5['get_seed_funding'].value_counts().tolist()
explode = (0, 0.1)
colors =  ['lightcoral','palegreen'] 

plt.pie(sizes, explode = explode, colors = colors ,labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=190)
plt.axis('equal')
plt.tight_layout()
plt.title("How many companies get seed funding?", fontdict=None, position= [0.48,1.1], size = 'x-large')

plt.show()

# %%
get_venture=(data5.get_seed_funding.sum())/len(data5['get_seed_funding'])
plt.rcParams['figure.figsize'] = 3,3
cmap = plt.get_cmap("Dark2")
outer_colors = cmap(np.arange(2)*13)
plt.pie([get_venture,1-get_venture], radius=2, colors=outer_colors,labels=['Get Seed Fund','No'],autopct='%1.1f%%',
       wedgeprops=dict(width=0.5, edgecolor='w'))
plt.title('How Many Companies Get Seed Funding',pad=100)
plt.show()

# %% [markdown]
# > **How much seed funding for well-known Companies?**

# %%
print("The average of seed funding is around ",data['seed'][data['seed'] != 0].mean(), "$")
# Out:
# The average of seed funding is around  776350.5418021533 $

# %%
data5[data5['seed']!=0].sort_values(by='seed',ascending=False).head(2)
# Out:
#                                           permalink  ... get_seed_funding
# 13614                  /organization/engine-ecology  ...                1
# 39813  /organization/space-exploration-technologies  ...                1
#
# [2 rows x 41 columns]

# %%
Facebook_seed = data5['seed'][data['name']=="Facebook"].values[0]
Amazon_seed  = data5['seed'][data['name']=="Amazon"].values[0]
Netflix_seed  = data5['seed'][data['name']=="Netflix"].values[0]
Google_seed  = data5['seed'][data['name']=="Google"].values[0]
Alibaba_seed  = data5['seed'][data['name']=="Alibaba"].values[0]


print('Facebook_seed :' ,Facebook_seed)
print('Amazon_seed :' ,Amazon_seed)
print('Netflix_seed :' ,Netflix_seed)
print('Google_seed :' ,Google_seed)
print('Alibaba_seed :' ,Alibaba_seed)
# Out:
# Facebook_seed : 0.0
# Amazon_seed : 0.0
# Netflix_seed : 0.0
# Google_seed : 0.0
# Alibaba_seed : 0.0

# %%
SpaceX_seed = data5['seed'][data['name']=="Space Exploration Technologies"].values[0]
Uber_seed  = data5['seed'][data['name']=="Uber"].values[0]
Dropbox_seed  = data5['seed'][data['name']=="Dropbox"].values[0]

print('SpaceX_seed :' ,SpaceX_seed)
print('Uber_seed :' ,Uber_seed)
print('Dropbox_seed :' ,Dropbox_seed)
# Out:
# SpaceX_seed : 100000000.0
# Uber_seed : 200000.0
# Dropbox_seed : 15000.0

# %%
plt.rcParams['figure.figsize'] = 15,6
plt.hist(withoutoutlier_seed['seed'][withoutoutlier_seed['seed']!=0].dropna(), bins=30,color = 'tan' )

plt.axvline(Facebook_seed,color='indigo',linestyle ="--")
plt.text(Facebook_seed+0, 0,"Facebook \n ( 0 $)")

plt.axvline(Uber_seed,color='black',linestyle ="--")
plt.text(Uber_seed+0.15, 2000,"      Uber \n ( 200000$ )")

plt.axvline(Dropbox_seed,color='violet',linestyle ="--")
plt.text(Dropbox_seed+0.15, 1000,"  Dropbox \n( 15000$ )")

plt.ylabel('Count')
plt.xlabel('Funding (usd)')
plt.title("Seed funding for well known companies", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 15,6
plt.hist(withoutoutlier_seed['seed'][withoutoutlier_seed['seed']!=0].dropna(), bins=30,color = 'navy' )

plt.axvline(SpaceX_seed,color='royalblue',linestyle ="--")
plt.text(SpaceX_seed+0.15, 200,"SpaceX \n ( 100M $ )")

plt.axvline(Uber_seed,color='black',linestyle ="--")
plt.text(Uber_seed+0.15, 2000,"      Uber \n ( 200000$ )")

plt.axvline(Dropbox_seed,color='violet',linestyle ="--")
plt.text(Dropbox_seed+0.15, 1000,"  Dropbox \n( 15000$ )")

plt.ylabel('Count')
plt.xlabel('Funding (usd)')
plt.title("Seed funding for well known companies", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %% [markdown]
# > **Funding from Angel Investor**

# %%
print("The average of angel fund is around ",data5['angel'][data5['angel'] != 0].mean(), "$")
# Out:
# The average of angel fund is around  1033615.6954298498 $

# %%
data5['get_angel_investor'] = data5['angel'].map(lambda a :1  if a > 0 else 0)
data5['get_angel_investor']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 49433    0
# 49434    0
# 49435    0
# 49436    0
# 49437    0
# Name: get_angel_investor, Length: 49437, dtype: int64

# %%
len(data5['get_angel_investor'])
# Out:
# 49437

# %%
angel_fund=(data5.get_angel_investor.sum())/len(data5['get_angel_investor'])
plt.rcParams['figure.figsize'] = 3,3
cmap = plt.get_cmap("Dark2")
outer_colors = cmap(np.arange(2)*13)
plt.pie([angel_fund,1-angel_fund], radius=2, colors=outer_colors,labels=['Get Angel Fund','No'],autopct='%1.1f%%',
       wedgeprops=dict(width=0.5, edgecolor='w'))
plt.title('How Many Companies Get Angel Fund',pad=100)
plt.show()

# %% [markdown]
# > **Venture Capital**

# %%
funding_information(data5,'gumi')
# Out:
# Company :  gumi
# Total Funding :  94000000.0  $
# Seed Funding :  0.0  $
# Angel Funding : 0.0  $
# Grant Funding :  0.0  $
# Product Crowd Funding :  0.0  $
# Equity Crowd Funding :  0.0  $
# Undisclode Funding :  0.0  $
# Convertible Note :  0.0  $
# Debt Financing :  0.0  $
# Private Equity :  0.0  $
# PostIPO Equity :  0.0  $
# PostIPO Debt :  0.0  $
# Secondary Market :  0.0  $
# Venture Funding :  94000000.0  $
# Round A funding :  0.0  $
# Round B funding :  0.0  $
# Round C funding :  0.0  $
# Round D funding :  0.0  $
# Round E funding :  0.0  $
# Round F funding :  26000000.0  $
# Round G funding :  19000000.0  $
# Round H funding :  49000000.0  $

# %%
data5['get_venture'] = data5['venture'].map(lambda v :1  if v > 0 else 0)
data5['get_venture']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 49433    0
# 49434    1
# 49435    0
# 49436    0
# 49437    1
# Name: get_venture, Length: 49437, dtype: int64

# %%
len(data5['get_venture'])
# Out:
# 49437

# %%
data['round_A'][data['round_A'] != 0].mean()
# Out:
# 6830906.178162835

# %%
get_venture=(data5.get_venture.sum())/len(data5['get_venture'])
plt.rcParams['figure.figsize'] = 3,3
cmap = plt.get_cmap("Accent")
outer_colors = cmap(np.arange(2)*13)
plt.pie([get_venture,1-get_venture], radius=2, colors=outer_colors,labels=['Get Venture Fund','No'],autopct='%1.1f%%',
       wedgeprops=dict(width=0.5, edgecolor='w'))
plt.title('How Many Companies Injected by Venture Capital',pad=100)
plt.show()

# %%
round_ = ['seed','angel','round_A','round_B','round_C','round_D','round_E','round_F','round_G','round_H']
amount = [data5['seed'][data5['seed'] != 0].mean(),
          data5['angel'][data5['angel'] != 0].mean(),
          data5['round_A'][data5['round_A'] != 0].mean(),
          data5['round_B'][data5['round_B'] != 0].mean(),
          data5['round_C'][data5['round_C'] != 0].mean(),
          data5['round_D'][data5['round_D'] != 0].mean(),
          data5['round_E'][data5['round_E'] != 0].mean(),
          data5['round_F'][data5['round_F'] != 0].mean(),
          data5['round_G'][data5['round_G'] != 0].mean(),
         data5['round_H'][data5['round_H'] != 0].mean()]

# %%
amount
# Out:
# [776350.5418021533,
#  1033615.6954298498,
#  6830906.178162835,
#  13549761.864145402,
#  21004716.314416636,
#  28308861.312111802,
#  32811904.83914729,
#  48796797.72674418,
#  83856543.3235294,
#  175900000.0]

# %%
plt.rcParams['figure.figsize'] = 15,8

height = amount
bars =  round_
y_pos = np.arange(len(bars))
plt.bar(y_pos, height , width=0.7, color= ['DarkOrchid','DarkRed','lightgrey','LightGreen','LightPink','LightSalmon','LightSeaGreen','LightSkyBlue','LightSlateGrey','DarkSlateBlue'])
plt.xticks(y_pos, bars)
plt.title("Average Seed, Angel and Venture Investment in each round", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %%
 data5[data5['round_H'] != 0].sort_values(by='round_H',ascending=False)
# Out:
#                       permalink        name  ... get_angel_investor get_venture
# 15569    /organization/flipkart    Flipkart  ...                  1           1
# 11260        /organization/deem        Deem  ...                  0           1
# 18233        /organization/gumi        gumi  ...                  0           1
# 24540  /organization/locondo-jp  Locondo.jp  ...                  0           1
#
# [4 rows x 43 columns]

# %%
data5.head(2)
# Out:
#                          permalink  ... get_venture
# 0            /organization/waywire  ...           0
# 1  /organization/tv-communications  ...           1
#
# [2 rows x 43 columns]

# %%
data5.to_csv('data_startup2014.csv', index=True)

# %% [markdown]
# # Hypothesis Testing

# %%
data5['M&A'] = data5['status'].map(lambda m :1  if m == 'acquired' else 0)

# %%
data5['ipo'] = data5['post_ipo_equity'].map(lambda i:1 if i>0 else 0)

# %%
data5['USA'] = data5['country_code'].map(lambda u:1 if u=='USA' else 0)

# %%
(data5['M&A'] == 1).value_counts()
# Out:
# False    45745
# True      3692
# Name: M&A, dtype: int64

# %%
data5['target'] =  data5['M&A'] | data5['ipo']

# %%
data5.head(2)
# Out:
#                          permalink                name  ... USA target
# 0            /organization/waywire            #waywire  ...   1      1
# 1  /organization/tv-communications  &TV Communications  ...   1      0
#
# [2 rows x 47 columns]

# %%
data5[(data5['M&A']==1) & (data5['ipo']==1)]
# Out:
#                                               permalink  ... target
# 8047   /organization/chelsea-therapeutics-international  ...      1
# 8664                            /organization/clearwire  ...      1
# 12467                 /organization/durata-therapeutics  ...      1
# 25278                       /organization/mako-surgical  ...      1
# 34585                              /organization/quture  ...      1
# 36522                               /organization/sabre  ...      1
# 48046                          /organization/wsp-global  ...      1
#
# [7 rows x 47 columns]

# %% [markdown]
# **Correlation**: a measure of the extent of interdependence between variables.
#
# Causation: the relationship between cause and effect between two variables.
#
# It is important to know the difference between these two and that correlation does not imply causation. Determining correlation is much simpler the determining causation as causation may require independent experimentation.

# %% [markdown]
# Pearson Correlation
#
# The Pearson Correlation measures the linear dependence between two variables X and Y.
#
# The resulting coefficient is a value between -1 and 1 inclusive, where:
#
#
#
# *   1: Total positive linear correlation.
# *   0: No linear correlation, the two variables most likely do not affect each other.
# *   -1: Total negative linear correlation.

# %% [markdown]
# P-value:
#
# What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
#
# p-value is  <  0.001: we say there is strong evidence that the correlation is significant.
# the p-value is  <  0.05: there is moderate evidence that the correlation is significant.
# the p-value is  <  0.1: there is weak evidence that the correlation is significant.
# the p-value is  >  0.1: there is no evidence that the correlation is significant.

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(data5['get_venture'], data5['target'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.12142100288299947  with a P-value of P = 1.0712088070539888e-161

# %%
corrmat = data5.corr(method='spearman')
f, ax = plt.subplots(figsize=(12, 10))

matrix = np.triu(corrmat)
sns.heatmap(corrmat, ax=ax, cmap="YlGnBu", linewidths=0.1, mask=matrix, annot = False)

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(data5['USA'], data5['target'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.09636358546268943  with a P-value of P = 2.647450733207692e-102

# %% [markdown]
# Since the p-value is  <  0.001, the correlation between getting venture and become successful startup is statistically significant, although the linear relationship is weak (~0.12), means getting venture is only have slight effect on becoming successful startup.

# %%
succ = data5[data5['target'] ==1]
succ.shape[0]

# %%
succ['country_code'].value_counts()
# Out:
# USA    2971
# GBR     156
# CAN     154
# DEU      73
# ISR      69
# FRA      51
# CHN      33
# AUS      25
# ESP      24
# IND      18
# IRL      17
# NLD      14
# DNK      13
# CHE      13
# SWE      13
# ITA      12
# FIN      11
# BEL      10
# SGP       9
# JPN       9
# NOR       6
# BRA       6
# KOR       6
# AUT       5
# RUS       5
# ARE       4
# ARG       4
# CHL       4
# BGR       3
# TUR       3
# NZL       3
# LTU       2
# HUN       2
# ZAF       2
# MYS       2
# CZE       2
# GRC       2
# MEX       2
# PRT       2
# LUX       1
# LBN       1
# MAF       1
# COL       1
# THA       1
# POL       1
# URY       1
# BMU       1
# LVA       1
# HKG       1
# Name: country_code, dtype: int64
